# %%
synonyms = {
    "ivory coast":"cote d'ivoire", 
    "côte d'ivoire":"cote d'ivoire", 
    "the bahamas":"bahamas",
    "trinidad and tobago":"trinidad tobago",
    "falkland islands":"falkland",
    "united states of america": "united states america",
    "east timor": "timor leste",
    "democratic republic of timor-leste": "timor leste",
    "brunei":"brunei darussalam",
    "northern cyprus":"cyprus",
    "solomon islands":"solomon",
    "republic of serbia":"serbia",
    "bosnia and herzegovina":"bosnia herzegovina",
    "united republic of tanzania":"tanzania",
    "somaliland":"somalia",
    "republic of the congo":"congo",
    "democratic republic of the congo":"democratic republic congo",
    "democratic republic of congo":"democratic republic congo",
    "guinea-bissau":"guinea bissau",
    "congo brazzaville":"democratic republic congo",
    "czech republic":"czechia",
    "united states": "united states america",
    'antigua and barbuda':'antigua barbuda',
    'cape verde':'cabo verde',
    'chinese taipei':'taiwan',
    "islamic republic of afghanistan":"afghanistan",
    "islamic republic of iran":"iran",
    "korea. republic of":"south korea",
    "kyrgyz republic":"kyrgyzstan",
    "lao people's democratic republic":"laos",
    "marshall islands":"marshall",
    "republic of congo":"congo",
    "republic of yemen":"yemen",
    "slovak republic":"slovakia",
    "st. kitts and nevis":"saint kitts nevis",
    "st. lucia":"saint lucia",
    "st. vincent and the grenadines":"saint vincent grenadines",
    "the gambia":"gambia",
    "serbia & montenegro":"serbia",
}
three_letter_codes = {'ven':'venezuela','xxk':'kosovo', 'afg': 'afghanistan', 'alb': 'albania', 'dza': 'algeria', 'asm': 'american samoa', 'and': 'andorra', 'ago': 'angola', 'aia': 'anguilla', 'ata': 'antarctica', 'atg': 'antigua barbuda', 'arg': 'argentina', 'arm': 'armenia', 'abw': 'aruba', 'aus': 'australia', 'aut': 'austria', 'aze': 'azerbaijan', 'bhs': 'bahamas', 'bhr': 'bahrain', 'bgd': 'bangladesh', 'brb': 'barbados', 'blr': 'belarus', 'bel': 'belgium', 'blz': 'belize', 'ben': 'benin', 'bmu': 'bermuda', 'btn': 'bhutan', 'bol': 'bolivia', 'bes': 'bonaire sint eustatius saba', 'bih': 'bosnia herzegovina', 'bwa': 'botswana', 'bvt': 'bouvet island', 'bra': 'brazil', 'iot': 'british indian ocean territory', 'brn': 'brunei darussalam', 'bgr': 'bulgaria', 'bfa': 'burkina faso', 'bdi': 'burundi', 'cpv': 'cabo verde', 'khm': 'cambodia', 'cmr': 'cameroon', 'can': 'canada', 'cym': 'cayman', 'caf': 'central african republic', 'tcd': 'chad', 'chl': 'chile', 'chn': 'china', 'cxr': 'christmas island', 'cck': 'cocos keeling', 'col': 'colombia', 'com': 'comoros', 'cod': 'democratic republic congo', 'cog': 'congo', 'cok': 'cook', 'cri': 'costa rica', 'hrv': 'croatia', 'cub': 'cuba', 'cuw': 'curacao', 'cyp': 'cyprus', 'cze': 'czechia', 'civ': "cote d'ivoire", 'dnk': 'denmark', 'dji': 'djibouti', 'dma': 'dominica', 'dom': 'dominican republic', 'ecu': 'ecuador', 'egy': 'egypt', 'slv': 'el salvador', 'gnq': 'equatorial guinea', 'eri': 'eritrea', 'est': 'estonia', 'swz': 'eswatini', 'eth': 'ethiopia', 'flk': 'falkland', 'fro': 'faroe', 'fji': 'fiji', 'fin': 'finland', 'fra': 'france', 'guf': 'french guiana', 'pyf': 'french polynesia', 'atf': 'french southern antarctic lands', 'gab': 'gabon', 'gmb': 'gambia', 'geo': 'georgia', 'deu': 'germany', 'gha': 'ghana', 'gib': 'gibraltar', 'grc': 'greece', 'grl': 'greenland', 'grd': 'grenada', 'glp': 'guadeloupe', 'gum': 'guam', 'gtm': 'guatemala', 'ggy': 'guernsey', 'gin': 'guinea', 'gnb': 'guinea bissau', 'guy': 'guyana', 'hti': 'haiti', 'hmd': 'heard island mcdonald', 'vat': 'holy see', 'hnd': 'honduras', 'hkg': 'hong kong', 'hun': 'hungary', 'isl': 'iceland', 'ind': 'india', 'idn': 'indonesia', 'irn': 'iran', 'irq': 'iraq', 'irl': 'ireland', 'imn': 'isle man', 'isr': 'israel', 'ita': 'italy', 'jam': 'jamaica', 'jpn': 'japan', 'jey': 'jersey', 'jor': 'jordan', 'kaz': 'kazakhstan', 'ken': 'kenya', 'kir': 'kiribati', 'prk': 'north korea', 'kor': 'south korea', 'kwt': 'kuwait', 'kgz': 'kyrgyzstan', 'lao': 'laos', 'lva': 'latvia', 'lbn': 'lebanon', 'lso': 'lesotho', 'lbr': 'liberia', 'lby': 'libya', 'lie': 'liechtenstein', 'ltu': 'lithuania', 'lux': 'luxembourg', 'mac': 'macau', 'mdg': 'madagascar', 'mwi': 'malawi', 'mys': 'malaysia', 'mdv': 'maldives', 'mli': 'mali', 'mlt': 'malta', 'mhl': 'marshall', 'mtq': 'martinique', 'mrt': 'mauritania', 'mus': 'mauritius', 'myt': 'mayotte', 'mex': 'mexico', 'fsm': 'micronesia', 'mda': 'moldova', 'mco': 'monaco', 'mng': 'mongolia', 'mne': 'montenegro', 'msr': 'montserrat', 'mar': 'morocco', 'moz': 'mozambique', 'mmr': 'myanmar', 'nam': 'namibia', 'nru': 'nauru', 'npl': 'nepal', 'nld': 'netherlands', 'ncl': 'new caledonia', 'nzl': 'new zealand', 'nic': 'nicaragua', 'ner': 'niger', 'nga': 'nigeria', 'niu': 'niue', 'nfk': 'norfolk island', 'mnp': 'northern mariana islands', 'nor': 'norway', 'omn': 'oman', 'pak': 'pakistan', 'plw': 'palau', 'pse': 'palestine', 'pan': 'panama', 'png': 'papua new guinea', 'pry': 'paraguay', 'per': 'peru', 'phl': 'philippines', 'pcn': 'pitcairn', 'pol': 'poland', 'prt': 'portugal', 'pri': 'puerto rico', 'qat': 'qatar', 'mkd': 'north macedonia', 'rou': 'romania', 'rus': 'russia', 'rwa': 'rwanda', 'reu': 'reunion', 'blm': 'saint barthelemy', 'shn': 'saint helena', 'kna': 'saint kitts nevis', 'lca': 'saint lucia', 'maf': 'saint martin', 'spm': 'saint pierre miquelon', 'vct': 'saint vincent grenadines', 'wsm': 'samoa', 'smr': 'san marino', 'stp': 'sao tome principe', 'sau': 'saudi arabia', 'sen': 'senegal', 'srb': 'serbia', 'syc': 'seychelles', 'sle': 'sierra leone', 'sgp': 'singapore', 'sxm': 'sint maarten', 'svk': 'slovakia', 'svn': 'slovenia', 'slb': 'solomon', 'som': 'somalia', 'zaf': 'south africa', 'sgs': 'south georgia south sandwich', 'ssd': 'south sudan', 'esp': 'spain', 'lka': 'sri lanka', 'sdn': 'sudan', 'sur': 'suriname', 'sjm': 'svalbard', 'swe': 'sweden', 'che': 'switzerland', 'syr': 'syria', 'twn': 'taiwan', 'tjk': 'tajikistan', 'tza': 'tanzania', 'tha': 'thailand', 'tls': 'timor leste', 'tgo': 'togo', 'tkl': 'tokelau', 'ton': 'tonga', 'tto': 'trinidad tobago', 'tun': 'tunisia', 'tur': 'turkey', 'tkm': 'turkmenistan', 'tca': 'turks caicos', 'tuv': 'tuvalu', 'uga': 'uganda', 'ukr': 'ukraine', 'are': 'united arab emirates', 'gbr': 'united kingdom', 'umi': 'united states minor outlying', 'usa': 'united states america', 'ury': 'uruguay', 'uzb': 'uzbekistan', 'vut': 'vanuatu', 'vnm': 'vietnam', 'vgb': 'british virgin', 'vir': 'united states virgin islands', 'wlf': 'wallis futuna', 'esh': 'western sahara', 'yem': 'yemen', 'zmb': 'zambia', 'zwe': 'zimbabwe', 'ala': 'aland'}
country_to_code = {v:k for k,v in three_letter_codes.items()}
for k,v in synonyms.items(): country_to_code[k] = country_to_code[v]

# %%
import pandas as pd
import geopandas as gpd

# %% [markdown]
# ### Clean the world polygon dataset

# %%
geoData = gpd.read_file('world.json')
geoData['Alpha‑3-code'] = geoData['admin'].str.lower().replace(country_to_code)
geoData.to_file("world.clean.json", driver="GeoJSON")

# %%
import geoplot as gplt
geoData = gpd.read_file('world.clean.json')
gplt.polyplot(geoData, figsize=(20, 4))
# Out:
# /home/ra414/.local/lib/python3.8/site-packages/geoplot/geoplot.py:885: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for subgeom in geom:
# <Axes: >

# %% [markdown]
# ### Clean the Germanwatch Climate Risk dataset

# %%
table_2019 = """"CRI Rank" "Country" "CRI score" "Fatalities in 2019 (Rank)" "Fatalities per 100 000 inhabitants (Rank)" "Losses in million US$ (PPP) (Rank)" "Losses per unit GDP in %(Rank)"
130 Albania 118.00 106 106 130 130
125 Algeria 105.17 65 95 122 127
23 Angola 32.33 44 50 22 14
130 "Antigua and Barbuda" 118.00 106 106 130 130
55 Argentina 60.00 60 86 28 50
113 Armenia 98.17 90 62 125 125
19 Australia 28.00 37 37 9 24
47 Austria 56.83 84 79 25 37
130 Azerbaijan 118.00 106 106 130 130
130 Bahrain 118.00 106 106 130 130
13 Bangladesh 23.50 7 29 20 28
130 Barbados 118.00 106 106 130 130
130 Belarus 118.00 106 106 130 130
64 Belgium 66.00 84 85 36 53
130 Belize 118.00 106 106 130 130
130 Benin 118.00 106 106 130 130
130 Bhutan 118.00 106 106 130 130
10 Bolivia 19.67 43 15 27 9
48 "Bosnia and Herzegovina" 57.83 98 82 45 20
117 Botswana 99.83 106 106 107 87
27 Brazil 33.67 5 32 17 58
130 "Brunei Darussalam" 118.00 106 106 130 130
119 Bulgaria 101.00 98 96 98 109
130 "Burkina Faso" 118.00 106 106 130 130
57 Burundi 61.83 26 10 121 102
84 Cambodia 75.83 60 63 97 86
68 Cameroon 67.33 32 27 104 107
62 Canada 65.67 90 104 16 40
130 "Cape Verde" 118.00 106 106 130 130
70 "Central African Republic" 67.50 98 92 89 17
130 Chad 118.00 106 106 130 130
25 Chile 33.00 52 59 12 8
32 China 42.83 4 83 3 42
116 "Chinese Taipei" 99.67 84 98 80 119
28 Colombia 36.33 17 18 37 64
16 Comoros 25.33 67 6 65 4
130 "Costa Rica" 118.00 106 106 130 130
129 "Côte d'Ivoire" 111.67 84 101 128 128
81 Croatia 75.17 106 106 51 41
130 Cyprus 118.00 106 106 130 130
107 "Czech Republic" 92.83 106 106 63 88
51 "Democratic Republic of Congo" 58.67 14 41 90 83
130 "Democratic Republic of Timor-Leste" 118.00 106 106 130 130
82 Denmark 75.50 72 49 75 104
75 Djibouti 73.00 64 5 124 120
88 Dominica 77.67 106 106 110 19
130 "Dominican Republic" 118.00 106 106 130 130
121 Ecuador 103.83 98 103 95 112
120 Egypt 102.00 58 99 112 122
103 "El Salvador" 91.83 80 67 111 113
130 Eritrea 118.00 106 106 130 130
83 Estonia 75.67 98 60 92 72
130 Eswatini 118.00 106 106 130 130
72 Ethiopia 69.33 39 74 67 81
75 Fiji 73.00 90 23 118 92
112 Finland 97.83 106 106 73 98
40 France 52.50 41 68 18 60
130 Gabon 118.00 106 106 130 130
108 Georgia 93.17 106 106 91 75
56 Germany 61.33 65 102 11 44
42 Ghana 53.33 29 30 71 80
36 Greece 45.00 50 34 44 54
130 Grenada 118.00 106 106 130 130
62 Guatemala 65.67 60 66 66 68
115 Guinea 99.17 72 72 127 126
130 Guinea-Bissau 118.00 106 106 130 130
130 Guyana 118.00 106 106 130 130
50 Haiti 58.33 60 51 94 47
79 Honduras 73.33 90 93 72 46
97 Hungary 85.83 106 106 55 71
100 Iceland 88.83 106 106 101 57
7 India 16.67 1 36 1 13
14 Indonesia 24.83 3 31 6 39
94 Iraq 84.33 56 77 76 110
123 Ireland 104.50 106 106 81 114
6 "Islamic Republic of Afghanistan" 16.00 11 11 33 15
18 "Islamic Republic of Iran" 27.00 22 45 8 21
128 Israel 108.83 90 88 129 129
35 Italy 43.50 46 70 7 34
130 Jamaica 118.00 106 106 130 130
4 Japan 14.50 9 20 2 18
130 Jordan 118.00 106 106 130 130
130 Kazakhstan 118.00 106 106 130 130
25 Kenya 33.00 15 16 49 51
130 Kiribati 118.00 106 106 130 130
60 "Korea. Republic of" 64.00 52 81 24 73
130 Kosovo 118.00 106 106 130 130
130 Kuwait 118.00 106 106 130 130
130 "Kyrgyz Republic" 118.00 106 106 130 130
45 "Lao People's Democratic Republic" 55.17 57 28 86 66
98 Latvia 86.83 106 106 79 62
44 Lebanon 54.67 72 55 60 43
61 Lesotho 64.67 106 106 58 6
101 Liberia 89.50 106 106 109 55
80 Libya 73.67 67 48 93 93
130 Lithuania 118.00 106 106 130 130
74 Luxembourg 72.83 106 106 53 33
29 Madagascar 40.33 19 14 83 56
5 Malawi 15.17 20 13 35 5
99 Malaysia 87.33 58 78 74 118
111 Maldives 97.33 106 106 114 76
90 Mali 79.67 52 58 108 101
68 Malta 67.33 106 106 54 16
130 "Marshall Islands" 118.00 106 106 130 130
58 Mauritania 63.00 76 44 96 59
125 Mauritius 105.17 106 106 113 100
54 Mexico 59.50 31 73 26 77
130 Micronesia 118.00 106 106 130 130
130 Moldova 118.00 106 106 130 130
22 Mongolia 31.67 50 9 62 30
89 Montenegro 78.00 80 8 126 123
90 Morocco 79.67 35 42 117 121
1 Mozambique 2.67 2 3 4 2
21 Myanmar 31.33 24 38 30 29
113 Namibia 98.17 98 75 119 111
12 Nepal 20.00 10 7 42 27
109 Netherlands 97.17 106 106 59 103
66 "New Zealand" 66.33 90 76 52 52
49 Nicaragua 58.00 72 52 82 45
9 Niger 18.17 17 12 46 11
73 Nigeria 70.00 27 84 47 89
130 "North Macedonia" 118.00 106 106 130 130
106 Norway 92.33 98 94 70 99
95 Oman 84.67 67 35 123 124
15 Pakistan 25.00 8 39 14 25
127 Panama 108.33 106 106 102 115
51 "Papua New Guinea" 58.67 49 17 105 82
20 Paraguay 30.00 52 22 38 23
46 Peru 56.33 37 43 57 79
17 Philippines 26.67 13 40 15 26
93 Poland 80.00 76 97 40 85
37 Portugal 48.33 67 61 29 36
130 "Puerto Rico" 118.00 106 106 130 130
130 Qatar 118.00 106 106 130 130
109 "Republic of Congo" 97.17 98 89 115 96
53 "Republic of Yemen" 59.33 42 46 84 69
123 Romania 104.50 106 106 77 116
39 Russia 50.67 33 80 13 49
42 Rwanda 53.33 45 21 99 67
130 Samoa 118.00 106 106 130 130
75 "Saudi Arabia" 73.00 48 65 50 105
70 Senegal 67.50 106 106 43 22
105 Serbia 92.00 106 106 78 78
130 Seychelles 118.00 106 106 130 130
86 "Sierra Leone" 76.50 67 54 116 84
130 Singapore 118.00 106 106 130 130
87 "Slovak Republic" 77.17 76 53 87 97
103 Slovenia 91.83 106 106 85 74
130 "Solomon Islands" 118.00 106 106 130 130
24 "South Africa" 32.50 16 26 31 48
8 "South Sudan" 17.33 12 4 64 10
32 Spain 42.83 47 69 10 31
30 "Sri Lanka" 41.83 33 24 48 61
130 "St. Kitts and Nevis" 118.00 106 106 130 130
130 "St. Lucia" 118.00 106 106 130 130
130 "St. Vincent and the Grenadines" 118.00 106 106 130 130
11 Sudan 19.83 22 25 23 12
130 Suriname 118.00 106 106 130 130
118 Sweden 100.50 106 106 69 108
96 Switzerland 85.50 90 87 61 94
122 Tajikistan 104.33 90 91 120 117
67 Tanzania 66.50 27 47 88 95
34 Thailand 43.17 36 64 19 38
3 "The Bahamas" 6.50 30 1 5 1
41 "The Gambia" 53.17 80 33 103 35
130 Togo 118.00 106 106 130 130
130 Tonga 118.00 106 106 130 130
130 "Trinidad and Tobago" 118.00 106 106 130 130
130 Tunisia 118.00 106 106 130 130
64 Turkey 66.00 40 71 34 90
130 Tuvalu 118.00 106 106 130 130
31 Uganda 42.17 21 19 68 63
85 Ukraine 76.17 76 100 41 70
130 "United Arab Emirates" 118.00 106 106 130 130
102 "United Kingdom" 90.83 84 105 39 106
90 Uruguay 79.67 84 56 100 91
130 Uzbekistan 118.00 106 106 130 130
75 Vanuatu 73.00 106 106 106 7
130 Venezuela 118.00 106 106 130 130
38 Vietnam 50.17 25 57 32 65
59 Zambia 63.33 80 90 56 32
2 Zimbabwe 6.17 6 2 21 3
NaN "United States" NaN NaN NaN NaN NaN"""

table_2000_2019=""""CRI Rank" "Country" "CRI score" "Average Fatalities 2000-2019 (Rank)" "Average Fatalities per 100000 inhabitants 2000-2019 (Rank)" "Average Losses in million US$(PPP) 2000-2019 (Rank)" "Average Losses per unit GDP in %2000-2019 (Rank)"
125 Albania 113.50 134 128 113 89
101 Algeria 92.83 34 65 87 153
87 Angola 84.00 51 70 79 117
56 "Antigua and Barbuda" 64.50 161 56 100 7
80 Argentina 77.00 61 113 21 77
156 Armenia 142.83 167 170 128 111
31 Australia 47.67 42 59 10 58
43 Austria 56.50 63 51 30 72
146 Azerbaijan 133.50 124 152 101 136
178 Bahrain 170.83 167 167 174 175
7 Bangladesh 28.33 9 37 13 37
148 Barbados 135.33 171 158 153 86
166 Belarus 156.17 136 161 145 167
53 Belgium 63.67 25 15 61 133
33 Belize 48.67 128 26 96 8
152 Benin 139.83 112 136 155 150
105 Bhutan 95.17 131 53 154 90
25 Bolivia 40.17 47 33 50 39
63 "Bosnia and Herzegovina" 68.17 122 111 37 14
143 Botswana 130.17 150 148 123 106
81 Brazil 79.50 17 98 16 124
176 "Brunei Darussalam" 167.50 167 151 178 179
68 Bulgaria 71.67 87 89 47 59
112 "Burkina Faso" 101.00 91 126 107 78
74 Burundi 74.50 75 69 126 54
14 Cambodia 36.17 38 35 53 28
140 Cameroon 128.17 83 123 136 152
93 Canada 87.33 77 133 15 83
150 "Cape Verde" 137.67 160 124 166 126
151 "Central African Republic" 138.83 136 147 163 120
115 Chad 104.67 104 138 106 71
83 Chile 81.33 84 116 32 70
41 China 56.33 5 106 1 60
36 "Chinese Taipei" 53.50 32 44 25 88
38 Colombia 54.83 24 49 33 87
97 Comoros 90.00 134 63 158 61
89 "Costa Rica" 84.50 96 81 89 80
153 "Côte d'Ivoire" 141.33 89 139 151 165
30 Croatia 47.00 53 19 63 64
142 Cyprus 129.67 149 99 147 142
82 "Czech Republic" 80.67 90 107 34 73
135 "Democratic Republic of Congo" 118.83 39 109 146 155
174 "Democratic Republic of Timor-Leste" 166.83 167 166 176 163
132 Denmark 118.00 146 160 52 95
65 Djibouti 70.33 107 32 141 55
11 Dominica 33.00 115 2 77 1
50 "Dominican Republic" 59.50 52 36 69 82
103 Ecuador 94.17 67 84 86 122
155 Egypt 142.17 76 157 119 172
28 "El Salvador" 43.67 65 41 57 29
129 Eritrea 115.83 163 168 124 36
158 Estonia 144.50 153 140 142 146
107 Eswatini 97.33 150 117 114 43
60 Ethiopia 66.50 27 92 54 67
19 Fiji 38.33 92 17 80 12
163 Finland 153.50 161 169 110 156
27 France 41.67 4 8 14 108
173 Gabon 165.83 155 150 180 180
104 Georgia 94.67 113 95 103 81
18 Germany 38.17 10 22 5 85
113 Ghana 101.33 54 80 112 141
75 Greece 75.00 69 68 49 98
24 Grenada 39.67 125 7 93 3
16 Guatemala 37.50 30 27 45 48
167 Guinea 159.83 128 159 173 170
109 Guinea-Bissau 99.17 140 102 149 51
119 Guyana 108.17 159 135 122 49
3 Haiti 13.67 13 4 41 10
44 Honduras 57.00 68 57 78 41
72 Hungary 74.00 59 48 65 112
177 Iceland 168.50 172 172 167 164
20 India 38.50 3 61 2 52
72 Indonesia 74.00 14 91 18 115
157 Iraq 143.17 93 155 120 168
137 Ireland 121.17 143 156 64 104
17 "Islamic Republic of Afghanistan" 37.83 12 14 75 56
97 "Islamic Republic of Iran" 90.00 41 110 29 125
136 Israel 120.33 108 122 92 139
22 Italy 39.00 6 9 12 99
54 Jamaica 63.83 111 77 70 24
57 Japan 64.83 21 90 4 92
141 Jordan 129.50 109 120 130 149
154 Kazakhstan 141.83 98 145 125 169
34 Kenya 52.00 36 67 42 50
131 Kiribati 116.33 172 172 160 11
91 "Korea. Republic of" 85.17 49 101 24 118
162 Kuwait 152.00 155 164 109 160
120 "Kyrgyz Republic" 109.67 77 52 159 159
52 "Lao People's Democratic Republic" 60.50 82 66 73 38
86 Latvia 82.83 106 62 99 84
132 Lebanon 118.00 114 114 108 129
109 Lesotho 99.17 146 132 121 32
164 Liberia 154.83 158 165 165 138
168 Libya 160.33 133 154 169 176
134 Lithuania 118.17 140 141 95 96
95 Luxembourg 89.00 94 13 134 140
12 Madagascar 34.67 31 38 55 23
62 Malawi 67.83 74 94 91 27
116 Malaysia 105.67 64 108 66 144
174 Maldives 166.83 172 172 171 157
121 Mali 110.50 95 129 116 97
147 Malta 134.00 163 142 139 109
172 "Marshall Islands" 164.83 172 172 179 147
85 Mauritania 82.00 103 79 105 63
139 Mauritius 124.17 143 104 138 128
59 Mexico 65.50 28 103 9 75
40 Micronesia 55.67 120 5 164 20
84 Moldova 81.67 131 118 71 26
48 Mongolia 59.17 88 46 83 46
106 Morocco 96.17 70 119 67 101
5 Mozambique 25.83 23 30 46 13
2 Myanmar 10.00 1 1 19 19
55 Namibia 64.33 81 28 111 69
10 Nepal 31.33 16 18 56 40
69 Netherlands 72.50 29 31 58 143
90 "New Zealand" 85.00 116 105 48 68
35 Nicaragua 53.00 66 40 88 42
64 Niger 68.67 60 74 98 53
114 Nigeria 104.33 26 115 68 151
108 "North Macedonia" 98.33 118 83 118 94
149 Norway 137.50 139 153 90 145
26 Oman 41.17 85 43 26 25
8 Pakistan 29.00 11 45 7 33
118 Panama 107.00 101 78 115 135
99 "Papua New Guinea" 90.83 72 50 135 119
61 Paraguay 67.00 102 100 40 30
45 Peru 57.67 33 58 39 79
4 Philippines 18.17 7 16 8 31
76 Poland 75.17 44 87 27 103
21 Portugal 38.67 20 12 36 76
1 "Puerto Rico" 7.17 19 3 6 6
180 Qatar 173.67 172 172 170 178
160 "Republic of Congo" 148.67 127 121 175 174
79 "Republic of Yemen" 76.17 48 71 85 91
41 Romania 56.33 56 73 22 57
32 Russia 48.50 2 6 17 130
117 Rwanda 105.83 73 72 150 134
70 Samoa 72.67 155 54 143 15
111 "Saudi Arabia" 100.33 57 93 51 154
138 Senegal 123.00 109 146 117 110
67 "Serbia & Montenegro" 70.83 96 112 35 35
168 Seychelles 160.33 172 172 172 137
92 "Sierra Leone" 85.83 55 29 156 123
179 Singapore 172.00 172 172 162 177
128 "Slovak Republic" 114.83 119 127 84 116
39 Slovenia 55.00 80 25 76 62
71 "Solomon Islands" 73.00 125 34 157 44
78 "South Africa" 76.00 45 97 31 93
100 "South Sudan" 92.67 71 75 131 102
29 Spain 46.50 8 11 23 113
23 "Sri Lanka" 39.50 35 42 28 45
130 "St. Kitts and Nevis" 116.00 172 172 144 18
51 "St. Lucia" 60.33 142 23 132 21
48 "St. Vincent and the Grenadines" 59.17 146 20 137 16
88 Sudan 84.33 46 88 74 105
171 Suriname 164.00 163 149 177 173
144 Sweden 131.33 138 163 62 131
45 Switzerland 57.67 40 24 44 107
47 Tajikistan 59.00 77 64 81 34
122 Tanzania 111.33 62 125 102 127
9 Thailand 29.83 22 60 3 17
6 "The Bahamas" 27.67 100 10 38 4
102 "The Gambia" 93.83 121 82 148 65
161 Togo 148.83 123 143 168 158
77 Tonga 75.67 163 76 129 5
159 "Trinidad and Tobago" 148.00 152 131 152 161
127 Tunisia 114.50 105 130 94 114
123 Turkey 111.83 58 137 43 148
125 Tuvalu 113.50 172 172 161 2
66 Uganda 70.67 50 85 72 66
94 Ukraine 88.83 37 86 60 132
165 "United Arab Emirates" 156.00 143 162 127 171
58 "United Kingdom" 65.00 18 55 20 121
96 Uruguay 89.83 117 96 82 74
170 Uzbekistan 161.17 153 171 140 166
37 Vanuatu 53.83 130 21 133 9
145 Venezuela 132.50 86 144 97 162
13 Vietnam 35.67 15 47 11 47
123 Zambia 111.83 99 134 104 100
15 Zimbabwe 37.33 43 39 59 22
NaN "United States" NaN NaN NaN NaN NaN"""

from io import StringIO 
pfile = StringIO(table_2019)
data = pd.read_csv(pfile, header=0, delimiter=r"\s+")
data = data.rename(columns={ n:"Germanwatch_"+n+"_2019" for n in data.columns.to_list() } )
data['Alpha‑3-code'] = data["Germanwatch_Country_2019"].str.lower().replace(country_to_code)
data.to_csv("GermanwatchCRI_2019.clean.csv")

pfile = StringIO(table_2000_2019)
data = pd.read_csv(pfile, header=0, delimiter=r"\s+")
data = data.rename(columns={ n:"Germanwatch_"+n+"_2000_2019" for n in data.columns.to_list() } )
data['Alpha‑3-code'] = data['Germanwatch_Country_2000_2019'].str.lower().replace(country_to_code)
data.to_csv("GermanwatchCRI_2000_2019.clean.csv")

# %% [markdown]
# ### Clean the EM-DAT data

# %%
data = pd.read_excel('emdat_public_2023_06_13_query_uid-bjBi9Y.xlsx', header=6)
data['Alpha‑3-code'] = data['ISO'].str.lower()
data = data.rename(columns={ n:"EMDAT_"+n+"_2019" for n in data.columns.to_list() if n != 'Alpha‑3-code'} )
data.to_csv("emdat_public_2023_06_13.clean.csv")
# Out:
# /home/ra414/.local/lib/python3.8/site-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %% [markdown]
# ### Clean the population and GDP worldbank data

# %%
pop = pd.read_csv('API_SP.POP.TOTL_DS2_en_csv_v2_5454896.csv',quotechar='"', header=2)
pop = pop.rename(columns={ n:"WorldBank_"+n+"_POP" for n in pop.columns.to_list() } )
pop["Alpha‑3-code"] = pop["WorldBank_Country Code_POP"].str.lower()
pop.to_csv("population.clean.csv")

gdp = pd.read_csv('API_NY.GDP.MKTP.CD_DS2_en_csv_v2_5551501.csv',quotechar='"', header=2)
gdp = gdp.rename(columns={ n:"WorldBank_"+n+"_GDP" for n in gdp.columns.to_list() } )
gdp["Alpha‑3-code"] = gdp["WorldBank_Country Code_GDP"].str.lower()
gdp.to_csv("gdp.clean.csv")

# %% [markdown]
# ### Clean the World Risk Poll data

# %%
data = pd.read_csv('lrf_wrp_2021_full_data.csv')
data['Alpha‑3-code'] = data['Country'].str.lower().replace(country_to_code)
data.to_csv("wrp_2021.clean.csv")
# Out:
# /tmp/ipykernel_403818/4218281214.py:1: DtypeWarning: Columns (7,8,9,10,16,17,20,21,22,28,31,32,33,34,35,36,37,38,41,43,46,47,48,49,50,51,52,53,54,56,57,58,59,60,66,67,68,69,70,71,72,73,74,75,76,77,78,81,84,101,224,226,227,228,229,230) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('lrf_wrp_2021_full_data.csv')

# %% [markdown]
# ### Merge all the country level CSVs (not the World Risk Poll or EMDAT)

# %%
GW1 = pd.read_csv("GermanwatchCRI_2019.clean.csv", index_col=0)
GW2 = pd.read_csv("GermanwatchCRI_2000_2019.clean.csv", index_col=0)
pop = pd.read_csv('population.clean.csv', index_col=0)
gdp = pd.read_csv('gdp.clean.csv', index_col=0)
#warning caused by chaotic mix of 30N 35W and 30 -35 in Latitude and Longitude columns

geoData = GW1
geoData = geoData.merge(GW2, left_on=['Alpha‑3-code'], right_on=['Alpha‑3-code'])
geoData = geoData.merge(pop, left_on=['Alpha‑3-code'], right_on=['Alpha‑3-code'])
geoData = geoData.merge(gdp, left_on=['Alpha‑3-code'], right_on=['Alpha‑3-code'])

geoData.to_csv("country_data.csv")
